# %% [markdown]
# <a href="https://colab.research.google.com/github/Oscarsalin12/Ejercicios_Extrasion_Base/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practica numero dos.

# %%
import pandas as pd
from google.colab import files
import matplotlib.pyplot as plt

# %%
uploaded = files.upload()
df = pd.read_csv('ventasnvo.csv')
# Out:
#      <input type="file" id="files-d88a15ca-2b21-48e9-ad7b-ca5894386389" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d88a15ca-2b21-48e9-ad7b-ca5894386389">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print("\n Encabezado del dataset")
print(df.head())
print("\n Informacon de las Variables")
print(df.info())
print("\n Estadistica del Dataset ")
print(df.describe())
# Out:
#  Encabezado del dataset
#    ID_Venta       Fecha    Categoria        Producto  Cantidad  Precio  \
# 0         1  2025-06-01      Laptops       Laptop HP         2    5939
# 1         2  2025-05-19  Perifericos   Microfono USB         6    8757
# 2         3  2026-03-31  Perifericos       Webcam HD        13    4774
# 3         4  2025-12-25   Accesorios  Audifonos Sony        11    3504
# 4         5  2025-05-25   Accesorios  Audifonos Sony        13    7713
#
#       MetodoPago
# 0       Efectivo
# 1       Efectivo
# 2         PayPal
# 3  Transferencia
# 4         PayPal
#
#  Informacon de las Variables
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID_Venta    120 non-null    int64
#  1   Fecha       120 non-null    object
#  2   Categoria   120 non-null    object
#  3   Producto    120 non-null    object
# ...

# %% [markdown]
# comando para detectar valores nulos

# %%
print("\n valores nulos")
print(df.isnull().sum())
# Out:
# ID_Venta      0
# Fecha         0
# Categoria     0
# Producto      0
# Cantidad      0
# Precio        0
# MetodoPago    0
# dtype: int64

# %%
print("\n cuenata de producto con su categoria")
print(df["Categoria"].value_counts())
print("\n Cuanta de metodos de pago")
print(df["MetodoPago"].value_counts())
# Out:
# Categoria
# Accesorios     35
# Perifericos    24
# Laptops        23
# Monitores      19
# Componentes    19
# Name: count, dtype: int64
# MetodoPago
# PayPal           35
# Transferencia    33
# Efectivo         27
# Tarjeta          25
# Name: count, dtype: int64

# %%
print(df.loc[df["Precio"].idxmax()])
# Out:
# ID_Venta                 84
# Fecha            2026-03-09
# Categoria       Componentes
# Producto        Memoria RAM
# Cantidad                 11
# Precio                24809
# MetodoPago    Transferencia
# Name: 83, dtype: object

# %%
print("\n media de los precios")
print(df["Precio"].mean())
print("\n suma de la cantidad")
print(df["Cantidad"].sum())
# Out:
#  media de los precios
# 11637.933333333332
#
#  suma de la cantidad
# 954

# %%
df["Categoria"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Categoria'>

# %%
df["Categoria"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Categoria"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>
